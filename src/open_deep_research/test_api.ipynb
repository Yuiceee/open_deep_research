# %%
import os
os.environ["OPENAI_API_KEY"] = "432b1628-2b74-4fba-800a-3be77a46734f"
# os.environ["OPENAI_API_KEY"] = "19ad5e1b-1ac6-47c1-a869-d9a3111f6a16"
from langchain.chat_models import init_chat_model



llm = init_chat_model(
    model="doubao-seed-1.6-250615",
    temperature=0,
    model_provider="openai",
    base_url="https://ark.cn-beijing.volces.com/api/v3",
)

result = llm.invoke("怎么进行蛋白设计")
from IPython.display import Markdown
Markdown(result.content)
# Out:
# 蛋白设计是通过理性改造或从头构建氨基酸序列，使蛋白质获得特定结构、稳定性或功能（如催化、结合、自组装等）的过程。其核心是**“序列-结构-功能”的精准调控**，涉及结构生物学、计算生物学、生物化学等多学科交叉。以下是蛋白设计的通用流程和关键步骤，结合经典方法与前沿技术进行说明：
#
#
# ### **一、明确设计目标与功能需求**
# 首先需清晰定义设计目的，这决定后续策略选择。常见目标包括：
# - **功能设计**：如设计新酶（催化特定反应）、配体结合蛋白（抗体、受体激动剂/拮抗剂）、蛋白-蛋白相互作用调节剂等。
# - **结构设计**：如从头设计全新折叠类型（如TIM桶、β-螺旋）、自组装纳米结构（蛋白笼、纤维、膜孔）。
# - **性质优化**：如提高天然蛋白的稳定性（抗高温、极端pH）、可溶性、降低免疫原性等。
#
# **关键问题**：需明确功能指标（如酶活、结合亲和力）、结构约束（如目标折叠类型、活性位点位置）、应用场景（如体内/体外、工业催化等）。
#
#
# ### **二、获取或构建目标结构模型**
# 蛋白质的功能依赖其三维结构，因此需先确定“目标结构”（即希望设计的蛋白折叠成的构象）。结构来源包括：
#
#
# #### **1. 基于天然结构的改造（蛋白工程）**
# 若目标是优化天然蛋白（如提高稳定性、改变底物特异性），直接使用已知结构：
# - **实验结构**：从PDB数据库获取天然蛋白的晶体学、冷冻电镜或NMR结构（如PDB ID: 1A2Y）。
# - **同源建模**：若天然蛋白无结构，可基于同源序列（如>30%序列一致性）用SWISS-MODEL、MODELLER等工具构建模型。
#
#
# #### **2. 从头设计（De novo design）**
# 若需设计自然界不存在的全新结构或功能（如全新酶、人工纳米材料），需从头构建目标结构：
# - **基于结构模体（Motif）组装**：利用已知稳定结构单元（如α-螺旋束、β-折叠片、锌指）拼接成新骨架（如David Baker实验室设计的αβ桶结构）。
# - **计算生成骨架**：通过算法（如RosettaRemodel、ScaffoldDesign）生成符合几何约束（如氢键网络、疏水核心）的全新主链结构。
#
#
# ...

# %%
llm = init_chat_model(
    model="deepseek-v3-250324",
    temperature=0,
    model_provider="openai",
    base_url="https://ark.cn-beijing.volces.com/api/v3",
)

result = llm.invoke("怎么进行蛋白设计")
from IPython.display import Markdown
Markdown(result.content)
# Out:
# 蛋白质设计是一个多学科交叉的领域，结合了生物化学、计算生物学、结构生物学和机器学习等技术。以下是进行蛋白质设计的主要步骤和方法：
#
# ---
#
# ### **1. 明确设计目标**
# - **功能导向**：设计具有特定功能的蛋白（如酶催化、抗体结合、信号传导等）。
# - **结构导向**：设计特定折叠或结构的蛋白（如新型支架、纳米材料）。
# - **稳定性优化**：提高蛋白的热稳定性或化学稳定性。
#
# ---
#
# ### **2. 选择设计策略**
# #### **(1) 基于天然蛋白的改造**
# - **理性设计（Rational Design）**：通过已知结构和功能信息，定点突变关键残基（如酶的活性位点）。
# - **定向进化（Directed Evolution）**：通过随机突变+高通量筛选，迭代优化蛋白性能。
#
# #### **(2) 从头设计（De Novo Design）**
# - 从一级序列出发，设计自然界不存在的全新蛋白。
# - 常用工具：Rosetta、AlphaFold、ProteinMPNN等。
#
# ---
#
# ### **3. 计算工具与流程**
# #### **(1) 结构预测与建模**
# - **模板依赖**：使用同源建模（如SWISS-MODEL）基于已知结构模板构建模型。
# - **无模板**：用AlphaFold2、RoseTTAFold或Rosetta ab initio预测结构。
#
# #### **(2) 序列设计**
# - **逆折叠（Inverse Folding）**：给定目标结构，设计匹配的氨基酸序列。
#   - 工具：ProteinMPNN、RosettaDesign、ESM-IF（基于语言模型）。
# - **能量函数优化**：通过物理力场（如Rosetta能量函数）评估序列-结构的兼容性。
#
# #### **(3) 动态模拟与验证**
# - **分子动力学（MD）**：模拟蛋白折叠或功能运动（如GROMACS、AMBER）。
# - **稳定性检查**：计算ΔΔG（突变前后自由能变化）评估稳定性。
#
# ---
#
# ### **4. 实验验证**
# - **基因合成与表达**：将设计序列克隆到载体中，在大肠杆菌、酵母等系统中表达。
# ...

# %%
llm = init_chat_model(
    model="deepseek-r1-250528",
    temperature=0,
    model_provider="openai",
    base_url="https://ark.cn-beijing.volces.com/api/v3",
)

result = llm.invoke("怎么进行蛋白设计")
from IPython.display import Markdown
Markdown(result.content)
# Out:
# 蛋白设计是一个融合了生物化学、结构生物学、计算生物学和人工智能的跨学科领域。其核心目标是创造具有特定功能或性质的新蛋白质，或优化现有蛋白质。以下是进行蛋白设计的主要步骤和方法：
#
# ## 一、 明确设计目标
# *   **功能导向：** 设计具有特定催化活性（新酶）、结合特异性（抗体、受体拮抗剂/激动剂）、信号传导、结构支撑等功能的蛋白质。
# *   **性质导向：** 提高蛋白质的稳定性（耐热、耐酸碱、耐有机溶剂）、溶解性、表达量、折叠效率，或降低免疫原性等。
# *   **结构导向：** 设计具有特定三维结构（如对称纳米笼、新型折叠）的蛋白质。
#
# ## 二、 核心策略与方法
#
# 1.  **基于天然模板的设计：**
#     *   **同源建模：** 如果目标蛋白与已知结构的蛋白质序列相似性较高（>30%），可利用其作为模板构建模型，再针对特定区域进行突变优化。
#     *   **功能位点移植：** 将一个蛋白质的功能位点（如酶的活性中心）移植到另一个具有理想骨架性质的蛋白质支架上。
#     *   **定向进化：**
#         *   **原理：** 模拟自然选择，通过多轮随机突变（易错PCR、DNA shuffling等）和高通量筛选/选择，获得具有所需性质的变体。
#         *   **优点：** 不依赖详细的结构知识，适用于复杂功能的优化。
#         *   **缺点：** 实验工作量大，可能陷入局部最优解。
#
# 2.  **从头设计：**
#     *   **原理：** 不依赖天然模板，完全从氨基酸序列和物理化学原理出发，设计全新的蛋白质结构和功能。
#     *   **关键步骤：**
#         *   **定义目标折叠或功能位点几何形状。**
#         *   **主链设计：** 使用计算方法（如Rosetta）生成符合目标拓扑结构（如α螺旋束、β折叠桶）的稳定主链构象。参数包括主链二面角、氢键网络、堆积等。
#         *   **序列设计：** 在固定或采样的主骨架上，为每个氨基酸位置寻找最优的氨基酸类型，使设计的序列能够折叠成目标结构并满足功能要求。考虑因素包括：
# ...
